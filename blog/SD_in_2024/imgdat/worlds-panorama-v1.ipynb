# %%
#@title Parameters

#@markdown # Token is Requied!

#@markdown get a token from https://huggingface.co/settings/tokens \
huggingface_user_token = "" #@param {type:"string"}

#@markdown SD model name
model_name = "runwayml/stable-diffusion-v1-5" #@param {type:"string"}


#@markdown #Images panorama settings

prompt = "City of the future with a hint of cyberpunk, photorealistic, 8k, digital art" #@param {type:"string"}

num_images = 6 #@param {type:"number"}
base_width = 768  #@param {type:"number"}
base_height = 512  #@param {type:"number"}
num_steps = 20  #@param {type:"number"}
inpaint_strength = 0.75  #@param {type:"number"}

# %% [markdown]
# # In the end
#
# Save or copy panorama image and upload to, to view
# https://renderstuff.com/tools/360-panorama-web-viewer/

# %%
# !nvidia-smi

# %%
# !pip install -qU diffusers transformers scipy ftfy ipywidgets

# %%
# !mkdir -p ~/.huggingface
# !echo -n $huggingface_user_token > ~/.huggingface/token

# %%
from tqdm import tqdm, notebook

notebook.tqdm = tqdm

# %%
import torch

torch.set_grad_enabled(False)

# %%
import torch
from diffusers import StableDiffusionPipeline, StableDiffusionInpaintPipelineLegacy

# %%
generate = StableDiffusionPipeline.from_pretrained(
    model_name, 
    use_auth_token=True,
    torch_dtype=torch.float16, 
    revision="fp16",
).to('cuda')

# %%
#inpaint = StableDiffusionInpaintPipeline(
inpaint = StableDiffusionInpaintPipelineLegacy(
    vae=generate.vae,
    unet=generate.unet,
    scheduler=generate.scheduler,
    tokenizer=generate.tokenizer,
    text_encoder=generate.text_encoder,
    safety_checker=generate.safety_checker,
    feature_extractor=generate.feature_extractor,
).to('cuda')

# %%
# Generate images
imgs = []
with torch.autocast('cuda'):
    for _ in range(num_images):
        img = generate(
            prompt=prompt,
            num_inference_steps=num_steps,
            width=base_width,
            height=base_height,
        ).images[0]
        display(img)
        imgs.append(img)

# %%
# Stitch images
import numpy as np
from PIL import Image, ImageDraw

output = imgs[0]

for img in tqdm(imgs[1:] + [imgs[0]]):
    w,h = output.size
    new = Image.new('RGB', (base_width, base_height))
    new.paste(output, (-w+base_width//2, 0))
    new.paste(img, (base_width//2, 0))

    msk = Image.new('L', (base_width, base_height))
    drw = ImageDraw.Draw(msk)
    drw.rectangle((base_width//4, 0, 3*base_width//4, base_height), fill=255)

    with torch.autocast("cuda"):
        merged = inpaint(
            prompt=prompt,
            num_inference_steps=num_steps,
            image=new,
            mask_image=msk,
            strength=inpaint_strength,
        ).images[0]

    new = Image.new('RGB', (w+base_width, base_height))
    new.paste(output, (0, 0))
    new.paste(merged, (w-base_width//2, 0))
    img = img.crop((base_width//2, 0, base_width, base_height))
    new.paste(img, (w+base_width//2, 0))
    output = new

w, h = output.size
output = output.crop((base_width//2, 0, w-base_width//2, h))

# %%
# add borders
w, h = output.size
panorama = Image.new('RGB', (w, 3*h))
panorama.paste(output, (0, h))
display(panorama)
